# %%
import pandas as pd

# %%
with open("silver/Dados_Betfair_Exchange_HT00.csv", 'r', encoding='utf-8') as f:
    lines = f.readlines()
    print(f"Total lines: {len(lines)}")
    print(f"Line 41002: {lines[41001]}")
# Out:
# Total lines: 82001
# Line 41002: 2024-03-16;Club Leon;Puebla;1;0;2;1;0
